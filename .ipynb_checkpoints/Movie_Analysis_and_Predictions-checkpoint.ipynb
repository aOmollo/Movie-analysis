# %% [markdown]
# # MOVIE ANALYSIS AND PREDICTIONS

# %%
#import necessary libraries for the whole project-Analysis and Modelling 
import pandas as pd
import zipfile #to extract files from zipfile
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#View contents of directory
# %ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is E2A6-39CF
#
#  Directory of C:\Users\hp\Desktop\Movie Analysis
#
# 05/28/2024  03:36 PM    <DIR>          .
# 05/28/2024  03:36 PM    <DIR>          ..
# 05/27/2024  01:07 PM    <DIR>          .ipynb_checkpoints
# 05/27/2024  01:40 PM    <DIR>          dsc-phase-1-project-master
# 05/27/2024  01:29 PM        48,188,554 dsc-phase-1-project-master.zip
# 05/28/2024  03:36 PM           298,306 Movie_Analysis_and_Predictions.ipynb
# 05/27/2024  01:31 PM    <DIR>          path
#                2 File(s)     48,486,860 bytes
#                5 Dir(s)   4,804,898,816 bytes free

# %%
#Extract the ZipFile

zipfile_path = "dsc-phase-1-project-master.zip"
directory = r"C:\Users\hp\Desktop\Movie Analysis"

with zipfile.ZipFile(zipfile_path,"r") as zip_ref:
    zip_ref.extractall(directory)

#list zipfile contents extracted
#import os

import os
files_extracted = os.listdir(directory)

#View extracted files
print("Files Extracted:", files_extracted)
# Out:
# Files Extracted: ['.git', '.ipynb_checkpoints', 'dsc-phase-1-project-master', 'dsc-phase-1-project-master.zip', 'Movie_Analysis_and_Predictions.ipynb', 'path']

# %%
#get all files in the zip folder name dsc-phase-1-project-master.zip
#zip-ref is defined above 
zip_contents = zip_ref.namelist()

# Display all files
print("Contents of dsc-phase-1-project-master.zip:")
for item in zip_contents:
    print(item)
# Out:
# Contents of dsc-phase-1-project-master.zip:
# dsc-phase-1-project-master/
# dsc-phase-1-project-master/.canvas
# dsc-phase-1-project-master/.gitignore
# dsc-phase-1-project-master/CONTRIBUTING.md
# dsc-phase-1-project-master/LICENSE.md
# dsc-phase-1-project-master/README.md
# dsc-phase-1-project-master/awesome.gif
# dsc-phase-1-project-master/student.ipynb
# dsc-phase-1-project-master/zippedData/
# dsc-phase-1-project-master/zippedData/bom.movie_gross.csv.gz
# dsc-phase-1-project-master/zippedData/imdb.name.basics.csv.gz
# dsc-phase-1-project-master/zippedData/imdb.title.akas.csv.gz
# dsc-phase-1-project-master/zippedData/imdb.title.basics.csv.gz
# dsc-phase-1-project-master/zippedData/imdb.title.crew.csv.gz
# dsc-phase-1-project-master/zippedData/imdb.title.principals.csv.gz
# dsc-phase-1-project-master/zippedData/imdb.title.ratings.csv.gz
# dsc-phase-1-project-master/zippedData/rt.movie_info.tsv.gz
# dsc-phase-1-project-master/zippedData/rt.reviews.tsv.gz
# ...

# %% [markdown]
# # Analysis and Prediction of the Movies based on Gross Income Per Year

# %%
#Import pandas and preview file as dataframe 
import pandas as pd

# Path to the gzip compressed CSV file
movie_gross = "dsc-phase-1-project-master/zippedData/bom.movie_gross.csv.gz"

# Read the gzip compressed CSV file into a DataFrame
movie_gross_df = pd.read_csv(movie_gross, compression='gzip')

# Display the DataFrame
movie_gross_df
# Out:
#                                             title      studio  domestic_gross  \
# 0                                     Toy Story 3          BV     415000000.0
# 1                      Alice in Wonderland (2010)          BV     334200000.0
# 2     Harry Potter and the Deathly Hallows Part 1          WB     296000000.0
# 3                                       Inception          WB     292600000.0
# 4                             Shrek Forever After        P/DW     238700000.0
# ...                                           ...         ...             ...
# 3382                                    The Quake       Magn.          6200.0
# 3383                  Edward II (2018 re-release)          FM          4800.0
# 3384                                     El Pacto        Sony          2500.0
# 3385                                     The Swan  Synergetic          2400.0
# 3386                            An Actor Prepares       Grav.          1700.0
#
#      foreign_gross  year
# ...

# %% [markdown]
# #### Data Understanding

# %%
#check for general data information
movie_gross_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3387 entries, 0 to 3386
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           3387 non-null   object
#  1   studio          3382 non-null   object
#  2   domestic_gross  3359 non-null   float64
#  3   foreign_gross   2037 non-null   object
#  4   year            3387 non-null   int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 132.4+ KB

# %%
#change datatype of foreign_gross to float64
#replace the commas in the values with space to allow conversation
movie_gross_df["foreign_gross"] = movie_gross_df["foreign_gross"].str.replace(',', '').astype(float)

#preview datatype
movie_gross_df["foreign_gross"].dtype
# Out:
# dtype('float64')

# %%
#check for duplicates
movie_gross_df.duplicated().sum()
# Out:
# 0

# %%
#Check missing values
movie_gross_df.isna().sum()
# Out:
# title                0
# studio               5
# domestic_gross      28
# foreign_gross     1350
# year                 0
# dtype: int64

# %%
#Stastical Summary of the dataframe
movie_gross_df.describe().T
# Out:
#                  count          mean           std     min        25%  \
# domestic_gross  3359.0  2.874585e+07  6.698250e+07   100.0   120000.0
# foreign_gross   2037.0  7.487281e+07  1.374106e+08   600.0  3700000.0
# year            3387.0  2.013958e+03  2.478141e+00  2010.0     2012.0
#
#                        50%         75%          max
# domestic_gross   1400000.0  27900000.0  936700000.0
# foreign_gross   18700000.0  74900000.0  960500000.0
# year                2014.0      2016.0       2018.0

# %%
#Stastical Summary of domestic and foreign gross, omit the year is not necessary
print(movie_gross_df["domestic_gross"].describe(), "\n\n", movie_gross_df["foreign_gross"].describe())
# Out:
# count    3.359000e+03
# mean     2.874585e+07
# std      6.698250e+07
# min      1.000000e+02
# 25%      1.200000e+05
# 50%      1.400000e+06
# 75%      2.790000e+07
# max      9.367000e+08
# Name: domestic_gross, dtype: float64
#
#  count    2.037000e+03
# mean     7.487281e+07
# std      1.374106e+08
# min      6.000000e+02
# 25%      3.700000e+06
# 50%      1.870000e+07
# 75%      7.490000e+07
# max      9.605000e+08
# Name: foreign_gross, dtype: float64

# %%
# Create subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 4))

# Plot histogram for domestic gross
ax1.hist(movie_gross_df["domestic_gross"], bins=10, color='lightblue', alpha=0.7)
ax1.set_xlabel('Domestic Gross')
ax1.set_ylabel('Frequency')
ax1.set_title('Distribution of Domestic Gross')

# Plot histogram for foreign gross
ax2.hist(movie_gross_df["foreign_gross"], bins=10, color='grey', alpha=0.7)
ax2.set_xlabel('Foreign Gross')
ax2.set_ylabel('Frequency')
ax2.set_title('Distribution of Foreign Gross')

# Adjust layout
plt.tight_layout()

# Show plot
plt.show()

# %% [markdown]
# ### Data Wrangling

# %% [markdown]
# The data is skewed. The best method to deal with missing values for domestic and foreign_gross in this case is using regression imputations. This will address skewness and help models to predict missing values based on other variables in the dataset. This approach can capture complex relationships in the data but requires careful model selection and validation.

# %%
#drop missing values in studio 
movie_gross_df.dropna(subset=["studio"], inplace = True)

# %% [markdown]
# ### Exploratory Data Analysis

# %%
#check for top ten highest domestic gross income movies
top_domesticmarket_movies = movie_gross_df.sort_values(by="domestic_gross",ascending = False).head(10)
top_domesticmarket_movies
# Out:
#                              title studio  domestic_gross  foreign_gross  year
# 1872  Star Wars: The Force Awakens     BV     936700000.0         1131.6  2015
# 3080                 Black Panther     BV     700100000.0    646900000.0  2018
# 3079        Avengers: Infinity War     BV     678800000.0         1369.5  2018
# 1873                Jurassic World   Uni.     652300000.0         1019.4  2015
# 727          Marvel's The Avengers     BV     623400000.0    895500000.0  2012
# 2758      Star Wars: The Last Jedi     BV     620200000.0    712400000.0  2017
# 3082                 Incredibles 2     BV     608600000.0    634200000.0  2018
# 2323  Rogue One: A Star Wars Story     BV     532200000.0    523900000.0  2016
# 2759   Beauty and the Beast (2017)     BV     504000000.0    759500000.0  2017
# 2324                  Finding Dory     BV     486300000.0    542300000.0  2016

# %% [markdown]
# **Interpretation**
# The top ten films with the highers domestic gross were mostly produced by BV and Uni. Studios. However, the films earned different amounts in the foreign gross. The foreign gross differed in the films that earned most in domestic market.

# %%
#visualize the highest domestic paying films
plt.figure(figsize=(10, 6))

plt.plot(top_domesticmarket_movies['title'], top_domesticmarket_movies['domestic_gross'],marker='o', color='black',linestyle = "-" )
plt.xlabel('Movie Title')
plt.ylabel('Domestic Gross Income')
plt.title('Top Ten Highest Grossing Movies')
plt.xticks(rotation=45, ha='right')
plt.grid()
plt.tight_layout()
plt.show()
print("                             Top ten films that earned the highest domestic gross")
# Out:
#                              Top ten films that earned the highest domestic gross

# %%
#visualize the best Studio
plt.figure(figsize=(10, 6))

plt.bar(top_domesticmarket_movies['studio'], top_domesticmarket_movies['domestic_gross'])
plt.xlabel('Movie Studio')
plt.ylabel('Domestic Gross Income')
plt.title('Studio Producing The Top Ten Highest Grossing Movies')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
print("                                 BV Studio produced the most films that earned the most domestic gross")
# Out:
#                                  BV Studio produced the most films that earned the most domestic gross

# %%
#check for top ten highest foreign gross income movies
top_foreignmarket_movies = movie_gross_df.sort_values(by="foreign_gross",ascending = False).head(10)
top_foreignmarket_movies
# Out:
#                                             title studio  domestic_gross  \
# 328   Harry Potter and the Deathly Hallows Part 2     WB     381000000.0
# 1875                      Avengers: Age of Ultron     BV     459000000.0
# 727                         Marvel's The Avengers     BV     623400000.0
# 3081               Jurassic World: Fallen Kingdom   Uni.     417700000.0
# 1127                                       Frozen     BV     400700000.0
# 2764                               Wolf Warrior 2     HC       2700000.0
# 1477              Transformers: Age of Extinction   Par.     245400000.0
# 1876                                      Minions   Uni.     336000000.0
# 3083                                      Aquaman     WB     335100000.0
# 1128                                   Iron Man 3     BV     409000000.0
#
#       foreign_gross  year
# 328     960500000.0  2011
# 1875    946400000.0  2015
# 727     895500000.0  2012
# 3081    891800000.0  2018
# 1127    875700000.0  2013
# ...

# %%
#visualize filsm films with highest foreign gross
plt.figure(figsize = (9,6) )
colors = ["blue", "lightblue", "skyblue","green","lightgreen","gold","salmon","grey","lightgrey","black"] 
plt.barh(top_foreignmarket_movies["title"], top_foreignmarket_movies["foreign_gross"], color=colors)

plt.title("Films with Highest Foreign_gross")
plt.xlabel("Foreign_gross")
plt.ylabel("Film Title")
plt.xticks(rotation =45, ha="right")
plt.tight_layout()
plt.show()
print("                         films with the highest Foreign gross")
# Out:
#                          films with the highest Foreign gross

# %%
#visualize studios that produced films with highest foreign gross
plt.figure(figsize = (9,6) )
plt.scatter(top_foreignmarket_movies["studio"], top_foreignmarket_movies["foreign_gross"])

plt.title("Studio Producing Films with Highest Foreign_gross")
plt.xlabel("Studio")
plt.ylabel("Foreign_gross")
plt.xticks(rotation =45, ha="right")
plt.tight_layout()
plt.show()

print("                        WB(first) and BV(second) studios produced films with the highest Foreign gross")
# Out:
#                         WB(first) and BV(second) studios produced films with the highest Foreign gross

# %% [markdown]
# Analysis shows studio is a predictor of gross earned by a movie both internationally and locally. WB and BV are studios which produces films with highers foreign gross while BV leads in producing films with highest domestic gross

# %% [markdown]
# ## Modelling
# Create a model that predicts:
# a. foreign and
# b. domestic gross
# depending on the studio used to produce the film

# %% [markdown]
# ### A. Model to predict Domestic Gross

# %%
#Reuse original dataframe movie_gross_df
#Display first two observations

print('''Dependent variable is domestic_gross and independent variable studio \n ''')
movie_gross_df.head(2)
# Out:
# Dependent variable is domestic_gross and independent variable studio
#                         title studio  domestic_gross  foreign_gross  year
# 0                 Toy Story 3     BV     415000000.0    652000000.0  2010
# 1  Alice in Wonderland (2010)     BV     334200000.0    691300000.0  2010

# %%
#check for duplicates
movie_gross_df.duplicated().sum()
# Out:
# 0

# %%
#check missing values in domestic_gross and studio
movie_gross_df[["studio","domestic_gross"]].isna().sum()
# Out:
# studio             0
# domestic_gross    26
# dtype: int64
